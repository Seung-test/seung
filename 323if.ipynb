# %% [markdown]
# <a href="https://colab.research.google.com/github/Seung-test/seung/blob/main/323if.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1= int(input("숫자 입력 : "))
if(num1 < 10):
  print("num1은 10 미만")
else :
   if num1 < 100:
    print("num1은 10 이상 100미만")
   else :
       if num1 < 1000:
           print("num1은 100이상 1000미만")
       else :
           print("num1은 1000이상")
# Out:
# 숫자 입력 : 100
# num1은 100이상 1000미만

# %%
num1=int(input("숫자 입력"))
if num1 < 10:
  print("num1은 10미만")
elif num1 <100:
  print("num1은 10이상 100미만")
elif num1 <1000:
  print("num1은 100이상 1000미만")
else :
  print("num1은 1000이상")
# Out:
# 숫자 입력74
# num1은 10이상 100미만

# %%
weight = float(input("몸무게를 입력하세요 : "))

if weight <= 50.80:
  print("Flyweight")
elif weight <= 61.23:
    print("Lightweight")
elif weight <= 72.75:
    print("Middleweight")
else :
  print("Heavyweight")
# Out:
# 몸무게를 입력하세요 : 80.5
# Heavyweight

# %%
num = float(input("숫자를 입력하세요: "))

if num >= 0 and num <= 5:
    print("0이상 5이하")
# Out:
# 숫자를 입력하세요: 3
# 0이상 5이하

# %%
a, b = map(int, input("두 개의 정수를 입력하세요:").split())
if a > b:
    print(a - b)
else:
    print(b - a)
# Out:
# 두 개의 정수를 입력하세요:5 10
# 5

# %%
a, b, c = map(int, input("세 개의 정수를 입력하세요: ").split())

total = a + b + c
print("sum =", total)

if total % 2 == 0:
    print("2의 배수")
elif total % 3 == 0:
    print("3의 배수")
else:
    print("에러")
# Out:
# 세 개의 정수를 입력하세요: 5 6 9
# sum = 20
# 2의 배수

# %%
price = float(input("가격 입력: "))

if price >= 100:
    tax = price * 0.05
else:
    tax = 0
total = price + tax

print("옷의 가격 :", price,", 세금", tax, ", 전체가격", total)
# Out:
# 가격 입력: 255
# 옷의 가격 : 255.0 , 세금 12.75 , 전체가격 267.75

# %%
a, b, c = map(int, input().split())

if a<b :
  a=b
if a<c :
  a=c
print(a)
# Out:
# 1 3 5
# 5

# %%
a, b, c = map(int, input().split())

if a >=

# %%
a, b = map(int, input().split())

temp = a;
a = b;
b = temp;
print("x = ", a, "y =", b)
# Out:
# 3 5
# x =  5 y = 3

# %%
a, b = input().split()

temp = a;
a = b;
b = temp;

print("s1 =", a, "s2 =", b)
# Out:
# Hello World
# s1 = World s2 = Hello

# %%
a, b = map(int, input().split())

if a < b:
  temp = a;
  a = b;
  b = temp;

print(a, b)
# Out:
# 1 100
# 100 1

# %%
a, b = map(int, input("두 개의 정수를 입력하세요.").split())

if a<b :
  temp = a;
  a= b;
  b= temp;
print("큰 수에서 작은 수를 뺀 차는", a-b)
# Out:
# 두 개의 정수를 입력하세요.10 5
# 큰 수에서 작은 수를 뺀 차는 5

# %%
a, b = map(float, input("두개의 실수를 입력하세요.").split())

if a >= 4.0 and b >= 4.0:
  print("A")
elif a >= 3.0 and b >= 3.0:
  print("B")
else:
  print('C')
# Out:
# 두개의 실수를 입력하세요.3.5 3.5
# B

# %%
a, b = map(int, input("주사위를 두번 결과를 입력하세요.").split())

if a >= 4 and b >= 4:
  print("이겼습니다.")
elif a >= 4 or b >= 4:
  print("비겼습니다.")
else:
  print('졌습니다.')
# Out:
# 주사위를 두번 결과를 입력하세요.4 4
# 이겼습니다.

# %%
year = int(input())

if year % 4 == 0:
  if year % 100 == 0:
    if year % 400 == 0:
      print(year,"년은 윤년입니다.")
    else:
      print(year, "년은 윤년이 아닙니다.")
  else:
    print(year,"년은 윤년입니다.")
else:
  print(year, "년은 윤년이 아닙니다.")
# Out:
# 2012
# 2012 년은 윤년입니다.

# %%
user_ID = 1234
user_PW = 5678

ID = int(input("ID를 입력하세요"))

if ID == user_ID:
  PW = int(input("비밀번호를 입력하세요:"))
  if PW == user_PW:
     print("로그인 되었습니다.")
  else:
    print("비밀번호가 틀렸습니다.")
else:
  print("아이디가 틀렸습니다.")
# Out:
# ID를 입력하세요134
# 아이디가 틀렸습니다.
